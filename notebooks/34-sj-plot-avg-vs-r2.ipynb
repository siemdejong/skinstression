# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
r2 = np.array([0.6760630511597858,
            0.6248231637070529,
            0.7169894974176265,
            0.6955731350679979,
            0.6057486712577773,
            0.6742035275137563,
            0.7842719797615871,
            0.902196100745819,
            0.7638782337097305,
            0.6831415298521104,
            0.6290178813228501,
            0.5458825821198682,
            0.8074109378052663,
            0.5798900483418394,
            0.832886269576883,
            0.8778890486851355,
            0.5977668695507602,
            0.909035949252458,
            0.8288666770103673,
            -3.512803280321485])
mu_a = np.array([0.024365, 0.012147, 0.002608, -0.002969, 0.009699, 0.030204, 0.002976, 0.028226, 0.028062, 0.025468, 0.016294, -0.092951, -0.00843, 0.023525, -0.061135, 0.003429, -0.010419, -0.013936, -0.057228, 0.021357])
mu_k = np.array([-0.028084, 0.005448, 0.005304, 0.0122, 0.005764, 0.013145, 0.006772, -0.015081, -0.023014, 0.003657, 0.01471, 0.273281, 0.019239, -0.018722, 0.231377, 0.010749, 0.018215, 0.020127, 0.188216, 0.013897])
mu_xc = np.array([-0.001055, -9e-06, 0.001774, 0.001586, -0.000381, -0.00016, -0.001184, 5.2e-05, -0.000356, 0.000257, 4.5e-05, 0.000302, -0.000882, -0.001064, 0.001214, -0.000268, 0.0015, 0.001055, 0.000925, 0.000567])
std_a = np.array([0.04052, 0.032165, 0.044972, 0.052841, 0.036713, 0.06983, 0.029009, 0.049662, 0.045787, 0.044231, 0.033466, 0.144197, 0.034502, 0.052529, 0.106361, 0.032303, 0.061175, 0.055019, 0.103719, 0.03538])
std_k = np.array([0.066809, 0.038271, 0.037227, 0.099933, 0.039051, 0.145224, 0.056757, 0.052524, 0.060746, 0.068173, 0.070325, 0.512681, 0.066385, 0.049238, 0.48267, 0.05902, 0.156063, 0.131645, 0.419141, 0.078054])
std_xc = np.array([0.002736, 0.002357, 0.00259, 0.002622, 0.002212, 0.002171, 0.001896, 0.0024, 0.002566, 0.002321, 0.002285, 0.001923, 0.001625, 0.002436, 0.002524, 0.001735, 0.002256, 0.002229, 0.002112, 0.001982])

# %%
# plt.scatter(r2, np.abs(mu_a))
plt.scatter(r2, np.abs(mu_k))
# plt.scatter(r2, np.abs(mu_xc))
plt.xlim([0, 1])
# Out:
# (0.0, 1.0)

# %%
# plt.scatter(r2, std_a, label="a")
plt.scatter(r2, std_k, label="k")
# plt.scatter(r2, std_xc, label="xc")
plt.xlim([0, 1])
plt.legend()
